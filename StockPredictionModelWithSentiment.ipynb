# %%
# IMPORT THE LIBRARY
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\knc01\anaconda3\lib\site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\knc01\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\knc01\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\knc01\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\knc01\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\knc01\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\knc01\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
# !pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\knc01\anaconda3\lib\site-packages (0.5.1)

# %%
SENTIMENT_ANALYSIS = 1
if SENTIMENT_ANALYSIS:
    # !pip install newspaper3k
    # !pip install GoogleNews
    # !pip install nltk
    # !pip install newspaper
    # !pip install wordcloud
else:
    print("Sentiment analysis disabled")
# Out:
# Requirement already satisfied: newspaper3k in c:\users\knc01\anaconda3\lib\site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (4.12.2)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (9.4.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\knc01\anaconda3\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\knc01\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4)
# Requirement already satisfied: six in c:\users\knc01\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\knc01\anaconda3\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in c:\users\knc01\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.0.4)
# Requirement already satisfied: joblib in c:\users\knc01\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\knc01\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\knc01\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\knc01\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2023.7.22)
# Requirement already satisfied: requests-file>=1.4 in c:\users\knc01\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\knc01\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.9.0)
# Requirement already satisfied: colorama in c:\users\knc01\anaconda3\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# Requirement already satisfied: GoogleNews in c:\users\knc01\anaconda3\lib\site-packages (1.6.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\knc01\anaconda3\lib\site-packages (from GoogleNews) (4.12.2)
# Requirement already satisfied: dateparser in c:\users\knc01\anaconda3\lib\site-packages (from GoogleNews) (1.2.0)
# Requirement already satisfied: python-dateutil in c:\users\knc01\anaconda3\lib\site-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\knc01\anaconda3\lib\site-packages (from beautifulsoup4->GoogleNews) (2.4)
# Requirement already satisfied: pytz in c:\users\knc01\anaconda3\lib\site-packages (from dateparser->GoogleNews) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\knc01\anaconda3\lib\site-packages (from dateparser->GoogleNews) (2022.7.9)
# Requirement already satisfied: tzlocal in c:\users\knc01\anaconda3\lib\site-packages (from dateparser->GoogleNews) (5.2)
# Requirement already satisfied: six>=1.5 in c:\users\knc01\anaconda3\lib\site-packages (from python-dateutil->GoogleNews) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\knc01\anaconda3\lib\site-packages (from tzlocal->dateparser->GoogleNews) (2023.3)
# Requirement already satisfied: nltk in c:\users\knc01\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\knc01\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\knc01\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\knc01\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\knc01\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\knc01\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Collecting newspaper
#   Using cached newspaper-0.1.0.7.tar.gz (176 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   WARNING! You are attempting to install newspaper's python2 repository on python3. PLEASE RUN `$ pip3 install newspaper3k` for python3 or `$ pip install newspaper` for python2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: wordcloud in c:\users\knc01\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\knc01\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\knc01\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\knc01\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\knc01\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\knc01\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from datetime import datetime
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
if SENTIMENT_ANALYSIS:
    import nltk
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    from GoogleNews import GoogleNews
    from newspaper import Article
    from newspaper import Config
    from wordcloud import WordCloud, STOPWORDS
    import json
    nltk.download('vader_lexicon') #required for Sentiment Analysis
    nltk.download('punkt')
else:
    print("Sentiment analysis disabled")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\knc01\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\knc01\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from pyspark.ml import Pipeline
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql import SparkSession
from pyspark.sql import functions as sqlFn
from pyspark.sql.window import Window
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
#from ipynb.fs.full.SentimentAnalysis import GenerateCSVFile
from SentLib import GenerateCSVFile

# %%
# CREATE TICKER INSTANCE FOR AMAZON
amzn = yf.Ticker("AMZN")

# GET TODAYS DATE AND CONVERT IT TO A STRING WITH YYYY-MM-DD FORMAT (YFINANCE EXPECTS THAT FORMAT)
end_date = datetime.now().strftime('%Y-%m-%d')
if SENTIMENT_ANALYSIS:
    amzn_hist = amzn.history(start='2023-04-07',end='2024-04-07')
else:
    amzn_hist = amzn.history(start='2010-01-16',end='2024-04-01')
#print(amzn_hist)
amzn_hist.to_csv('amazon.csv')

# %%
#Generate Sentiment Analysis CSV file for Amazon with normalized sentiment of '1' or '0'
if SENTIMENT_ANALYSIS:
    GenerateCSVFile("AMZN",'sentiment_data.csv',365)
else:
    print("Sentiment analysis disabled")
# Out:
# Sentiment analysis for the period: 2024-04-15 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-14 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-13 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-12 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-11 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-10 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-09 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-08 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-07 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-06 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-05 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-04 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-03 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-02 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-04-01 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-31 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-30 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-29 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-28 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-27 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-26 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-25 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-24 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-23 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-22 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-21 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-20 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-19 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-18 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-17 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-16 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-15 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-14 to 2024-04-16
# Positive Sentiment: 0.00
# Neutral Sentiment: 9.00
# Negative Sentiment: 1.00
# Positive ......: 0.125
#
# Sentiment analysis for the period: 2024-03-13 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-12 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-11 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-10 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-09 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-08 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-07 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-06 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-05 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-04 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-03 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-02 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-03-01 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-29 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-28 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-27 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-26 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-25 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-24 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-23 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-22 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-21 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-20 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-19 to 2024-04-16
# Positive Sentiment: 0.00
# Neutral Sentiment: 9.00
# Negative Sentiment: 1.00
# Positive ......: 0.125
#
# Sentiment analysis for the period: 2024-02-18 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-17 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-16 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-15 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-14 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-13 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-12 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-11 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-10 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-09 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-08 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-07 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-06 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-05 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-04 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-03 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-02 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-02-01 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-31 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-30 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-29 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-28 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-27 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-26 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-25 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-24 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-23 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-22 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-21 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-20 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-19 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-18 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-17 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-16 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-15 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-14 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-13 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-12 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-11 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-10 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-09 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-08 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-07 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-06 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-05 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-04 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-03 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-02 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2024-01-01 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-31 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-30 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-29 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-28 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-27 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-26 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-25 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-24 to 2024-04-16
# Positive Sentiment: 0.00
# Neutral Sentiment: 9.00
# Negative Sentiment: 1.00
# Positive ......: 0.125
#
# Sentiment analysis for the period: 2023-12-23 to 2024-04-16
# Positive Sentiment: 1.00
# Neutral Sentiment: 8.00
# Negative Sentiment: 1.00
# Positive ......: 0.20000000000000004
#
# Sentiment analysis for the period: 2023-12-22 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-21 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-20 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-19 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-18 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-17 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-16 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-15 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-14 to 2024-04-16
# Positive Sentiment: 7.00
# Neutral Sentiment: 3.00
# Negative Sentiment: 0.00
# Positive ......: 0.7749999999999999
#
# Sentiment analysis for the period: 2023-12-13 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-12 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-11 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-10 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-09 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-08 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-07 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-06 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-05 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-04 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-03 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-02 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-12-01 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-30 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-29 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-28 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-27 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-26 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-25 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-24 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-23 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-22 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-21 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-20 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-19 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-18 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-17 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-16 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-15 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-14 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-13 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-12 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-11 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-10 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-09 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-08 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-07 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-06 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-05 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-04 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-03 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-02 to 2024-04-16
# Positive Sentiment: 6.00
# Neutral Sentiment: 4.00
# Negative Sentiment: 0.00
# Positive ......: 0.7
#
# Sentiment analysis for the period: 2023-11-01 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-31 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-30 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-29 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-28 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-27 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-26 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-25 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-24 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-23 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-22 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-21 to 2024-04-16
# Positive Sentiment: 5.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 0.00
# Positive ......: 0.625
#
# Sentiment analysis for the period: 2023-10-20 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-19 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-18 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-17 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-16 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-15 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-14 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-13 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-12 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-11 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-10 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-09 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-08 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-07 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-06 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-05 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-04 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-03 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-02 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-10-01 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-30 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-29 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-28 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-27 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-26 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-25 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-24 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-23 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-22 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-21 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-20 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-19 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-18 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-17 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-16 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-15 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-14 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-13 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-12 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-11 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-10 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-09 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-08 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-07 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-06 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-05 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-04 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-03 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-02 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-09-01 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-31 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-30 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-29 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-28 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-27 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-26 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-25 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-24 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-23 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-22 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-21 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-20 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-19 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-18 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-17 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-16 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-15 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-14 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-13 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-12 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-11 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-10 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-09 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-08 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-07 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-06 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-05 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-04 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-03 to 2024-04-16
# Positive Sentiment: 3.00
# Neutral Sentiment: 7.00
# Negative Sentiment: 0.00
# Positive ......: 0.475
#
# Sentiment analysis for the period: 2023-08-02 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-08-01 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-07-31 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-07-30 to 2024-04-16
# Positive Sentiment: 4.00
# Neutral Sentiment: 6.00
# Negative Sentiment: 0.00
# Positive ......: 0.55
#
# Sentiment analysis for the period: 2023-07-29 to 2024-04-16
# HTTP Error 429: Too Many Requests
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 #Generate Sentiment Analysis CSV file for Amazon with normalized sentiment of '1' or '0'
#       2 if SENTIMENT_ANALYSIS:
# ----> 3     GenerateCSVFile("AMZN",'sentiment_data.csv',365)
#       4 else:
#       5     print("Sentiment analysis disabled")
#
# File ~\SentLib.py:262, in GenerateCSVFile(ticker_symbol, CSVFileName, NumOfDays)
#     260 StockSentimentMap = {}
#     261 #for ticker_symbol in TICKER_SYMBOLS:
# --> 262 sentiment = process_sentiment(ticker_symbol, start_date_str, end_date_str)
#     263     #Normalize sentiment value to either '1' or '0'
#     264 if(sentiment >=0.7):
#
# File ~\SentLib.py:161, in process_sentiment(tickerSymbol, startDate, endDate)
#     159 neutral_list = []
#     160 negative_list = []
# --> 161 positive_list = []
#     163 #Iterating over the tweets in the dataframe
#     164 for news in news_df['Summary']:
#
# UnboundLocalError: cannot access local variable 'news_df' where it is not associated with a value

# %%
from pyspark.sql.functions import col, to_date
# Create a Spark session
spark = SparkSession.builder.appName("StockPredictionModel").getOrCreate()
#spark.conf.set("spark.sql.legacy.timeParserPolicy", "LEGACY")
if SENTIMENT_ANALYSIS:
    # Load the data from the CSV into a DataFrame
    df1 = spark.read.csv("amazon.csv", header=True, inferSchema=True)
    # Parse the date column to keep only the YY-MM-DD part
    df1 = df1.withColumn("parsed_date", to_date(col("Date"), "yyyy-MM-dd"))
else:
    df = spark.read.csv("amazon.csv", header=True, inferSchema=True)
    df1 = df
    print("Sentiment analysis disabled")

# %%
df1.show(30)
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+
# |               Date|              Open|              High|               Low|             Close|   Volume|Dividends|Stock Splits|parsed_date|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+
# |2023-04-10 00:00:00|100.95999908447266|102.19999694824219| 99.56999969482422|102.16999816894531| 37261200|      0.0|         0.0| 2023-04-10|
# |2023-04-11 00:00:00|100.80000305175781|             101.0| 99.01000213623047| 99.91999816894531| 60417800|      0.0|         0.0| 2023-04-11|
# |2023-04-12 00:00:00| 100.4000015258789|100.51000213623047| 97.70999908447266| 97.83000183105469| 56735000|      0.0|         0.0| 2023-04-12|
# |2023-04-13 00:00:00| 98.94999694824219|102.56999969482422| 98.70999908447266| 102.4000015258789| 67925100|      0.0|         0.0| 2023-04-13|
# |2023-04-14 00:00:00|102.06999969482422|103.19999694824219|101.11000061035156|102.51000213623047| 51450500|      0.0|         0.0| 2023-04-14|
# |2023-04-17 00:00:00|103.16000366210938| 103.7300033569336|101.58999633789062|102.73999786376953| 39919500|      0.0|         0.0| 2023-04-17|
# |2023-04-18 00:00:00|103.94999694824219|104.19999694824219| 101.5199966430664|102.30000305175781| 39790500|      0.0|         0.0| 2023-04-18|
# |2023-04-19 00:00:00|101.58000183105469|105.12000274658203|101.38999938964844|104.30000305175781| 58398900|      0.0|         0.0| 2023-04-19|
# |2023-04-20 00:00:00|103.52999877929688|            105.25|103.20999908447266|103.80999755859375| 57696900|      0.0|         0.0| 2023-04-20|
# |2023-04-21 00:00:00| 106.0999984741211| 108.1500015258789|105.08000183105469|106.95999908447266| 86774200|      0.0|         0.0| 2023-04-21|
# |2023-04-24 00:00:00|107.66000366210938| 109.2300033569336|105.06999969482422|106.20999908447266| 69575600|      0.0|         0.0| 2023-04-24|
# |2023-04-25 00:00:00|104.91000366210938|105.44999694824219|102.44999694824219|102.56999969482422| 65026800|      0.0|         0.0| 2023-04-25|
# |2023-04-26 00:00:00|105.04000091552734|106.62000274658203| 104.0999984741211| 104.9800033569336| 73803800|      0.0|         0.0| 2023-04-26|
# |2023-04-27 00:00:00|108.16000366210938|110.86000061035156|106.80000305175781|109.81999969482422|149961200|      0.0|         0.0| 2023-04-27|
# |2023-04-28 00:00:00| 107.7300033569336| 109.4800033569336|104.33000183105469|105.44999694824219|130565000|      0.0|         0.0| 2023-04-28|
# |2023-05-01 00:00:00|104.94999694824219| 105.2300033569336|101.81999969482422|102.05000305175781| 74728100|      0.0|         0.0| 2023-05-01|
# |2023-05-02 00:00:00|101.47000122070312| 103.9000015258789| 101.1500015258789|103.62999725341797| 73469400|      0.0|         0.0| 2023-05-02|
# |2023-05-03 00:00:00|103.73999786376953|105.95999908447266|103.27999877929688| 103.6500015258789| 65051900|      0.0|         0.0| 2023-05-03|
# |2023-05-04 00:00:00|104.04000091552734|105.38999938964844|103.30999755859375|             104.0| 45345500|      0.0|         0.0| 2023-05-04|
# |2023-05-05 00:00:00| 104.2699966430664|105.76000213623047|103.55000305175781|105.66000366210938| 56912900|      0.0|         0.0| 2023-05-05|
# |2023-05-08 00:00:00|105.04000091552734| 106.0999984741211|104.69999694824219|105.83000183105469| 49430900|      0.0|         0.0| 2023-05-08|
# |2023-05-09 00:00:00| 105.4800033569336|106.79000091552734|105.16000366210938|106.62000274658203| 44089400|      0.0|         0.0| 2023-05-09|
# |2023-05-10 00:00:00| 108.0999984741211|110.66999816894531|108.05000305175781|110.19000244140625| 78627600|      0.0|         0.0| 2023-05-10|
# |2023-05-11 00:00:00|111.02999877929688|113.27999877929688|110.48999786376953|112.18000030517578| 74924800|      0.0|         0.0| 2023-05-11|
# |2023-05-12 00:00:00|112.16000366210938|112.63999938964844|109.31999969482422|110.26000213623047| 49810100|      0.0|         0.0| 2023-05-12|
# |2023-05-15 00:00:00| 111.1500015258789|112.29000091552734|            109.25|111.19999694824219| 53011100|      0.0|         0.0| 2023-05-15|
# |2023-05-16 00:00:00|111.05000305175781|114.79000091552734|111.05000305175781| 113.4000015258789| 71472900|      0.0|         0.0| 2023-05-16|
# |2023-05-17 00:00:00|114.88999938964844|115.83000183105469|114.22000122070312|             115.5| 65655200|      0.0|         0.0| 2023-05-17|
# |2023-05-18 00:00:00|116.69000244140625| 118.5999984741211|116.33999633789062| 118.1500015258789| 73174100|      0.0|         0.0| 2023-05-18|
# |2023-05-19 00:00:00|118.16000366210938|118.30999755859375|115.69999694824219|            116.25| 54990200|      0.0|         0.0| 2023-05-19|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+
# only showing top 30 rows

# %%
if SENTIMENT_ANALYSIS:
    df2 = spark.read.csv("sentiment_data.csv", header=True, inferSchema=True)
    df2.show(30)
    df = df1.join(df2, df1["parsed_date"] == df2["Date"], "inner")
    df.show(8)
    #drop the extra "date"
    df = df.drop(df2["Date"])
    df = df.drop(df1["parsed_date"])
    df.show(8)
else:
    print("Sentiment analysis disabled")
# Out:
# +----------+------+---------+
# |      Date|Ticker|Sentiment|
# +----------+------+---------+
# |2024-04-15|  AMZN|        0|
# |2024-04-14|  AMZN|        0|
# |2024-04-13|  AMZN|        0|
# |2024-04-12|  AMZN|        0|
# |2024-04-11|  AMZN|        0|
# |2024-04-10|  AMZN|        0|
# |2024-04-09|  AMZN|        0|
# |2024-04-08|  AMZN|        0|
# |2024-04-07|  AMZN|        0|
# |2024-04-06|  AMZN|        0|
# |2024-04-05|  AMZN|        0|
# |2024-04-04|  AMZN|        0|
# |2024-04-03|  AMZN|        0|
# |2024-04-02|  AMZN|        0|
# |2024-04-01|  AMZN|        0|
# |2024-03-31|  AMZN|        0|
# |2024-03-30|  AMZN|        0|
# |2024-03-29|  AMZN|        0|
# |2024-03-28|  AMZN|        0|
# |2024-03-27|  AMZN|        0|
# |2024-03-26|  AMZN|        0|
# |2024-03-25|  AMZN|        0|
# |2024-03-24|  AMZN|        0|
# |2024-03-23|  AMZN|        0|
# |2024-03-22|  AMZN|        0|
# |2024-03-21|  AMZN|        0|
# |2024-03-20|  AMZN|        0|
# |2024-03-19|  AMZN|        0|
# |2024-03-18|  AMZN|        0|
# |2024-03-17|  AMZN|        0|
# +----------+------+---------+
# only showing top 30 rows
#
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+----------+------+---------+
# |               Date|              Open|              High|               Low|             Close|   Volume|Dividends|Stock Splits|parsed_date|      Date|Ticker|Sentiment|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+----------+------+---------+
# |2023-07-31 00:00:00| 133.1999969482422| 133.8699951171875| 132.3800048828125|133.67999267578125| 41901500|      0.0|         0.0| 2023-07-31|2023-07-31|  AMZN|        0|
# |2023-08-01 00:00:00| 133.5500030517578|133.69000244140625| 131.6199951171875|131.69000244140625| 42098500|      0.0|         0.0| 2023-08-01|2023-08-01|  AMZN|        0|
# |2023-08-02 00:00:00|130.14999389648438|130.22999572753906|126.81999969482422| 128.2100067138672| 51027600|      0.0|         0.0| 2023-08-02|2023-08-02|  AMZN|        0|
# |2023-08-03 00:00:00| 127.4800033569336|129.83999633789062|126.41000366210938|128.91000366210938| 88585200|      0.0|         0.0| 2023-08-03|2023-08-03|  AMZN|        0|
# |2023-08-04 00:00:00|141.05999755859375| 143.6300048828125|139.32000732421875|139.57000732421875|152938700|      0.0|         0.0| 2023-08-04|2023-08-04|  AMZN|        0|
# |2023-08-07 00:00:00|140.99000549316406| 142.5399932861328| 138.9499969482422|142.22000122070312| 71213100|      0.0|         0.0| 2023-08-07|2023-08-07|  AMZN|        0|
# |2023-08-08 00:00:00| 140.6199951171875|140.83999633789062| 138.4199981689453|139.94000244140625| 51710500|      0.0|         0.0| 2023-08-08|2023-08-08|  AMZN|        0|
# |2023-08-09 00:00:00|139.97000122070312|140.32000732421875|137.10000610351562|137.85000610351562| 50017300|      0.0|         0.0| 2023-08-09|2023-08-09|  AMZN|        0|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+-----------+----------+------+---------+
# only showing top 8 rows
#
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+------+---------+
# |               Date|              Open|              High|               Low|             Close|   Volume|Dividends|Stock Splits|Ticker|Sentiment|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+------+---------+
# |2023-07-31 00:00:00| 133.1999969482422| 133.8699951171875| 132.3800048828125|133.67999267578125| 41901500|      0.0|         0.0|  AMZN|        0|
# |2023-08-01 00:00:00| 133.5500030517578|133.69000244140625| 131.6199951171875|131.69000244140625| 42098500|      0.0|         0.0|  AMZN|        0|
# |2023-08-02 00:00:00|130.14999389648438|130.22999572753906|126.81999969482422| 128.2100067138672| 51027600|      0.0|         0.0|  AMZN|        0|
# |2023-08-03 00:00:00| 127.4800033569336|129.83999633789062|126.41000366210938|128.91000366210938| 88585200|      0.0|         0.0|  AMZN|        0|
# |2023-08-04 00:00:00|141.05999755859375| 143.6300048828125|139.32000732421875|139.57000732421875|152938700|      0.0|         0.0|  AMZN|        0|
# |2023-08-07 00:00:00|140.99000549316406| 142.5399932861328| 138.9499969482422|142.22000122070312| 71213100|      0.0|         0.0|  AMZN|        0|
# |2023-08-08 00:00:00| 140.6199951171875|140.83999633789062| 138.4199981689453|139.94000244140625| 51710500|      0.0|         0.0|  AMZN|        0|
# |2023-08-09 00:00:00|139.97000122070312|140.32000732421875|137.10000610351562|137.85000610351562| 50017300|      0.0|         0.0|  AMZN|        0|
# +-------------------+------------------+------------------+------------------+------------------+---------+---------+------------+------+---------+
# only showing top 8 rows

# %%
# drop any row having any Null 
df = df.dropna(how="any")

# %%
# openCloseChange
df = df.withColumn("openCloseChange", (df.Close - df.Open) / df.Open)

# %%
# maxDayChange
df = df.withColumn("maxDayChange", df.High - df.Low)

# %%
# dividend provided
df = df.withColumn("dividend", sqlFn.when(df["Dividends"] > 0, 1).otherwise(0))

# %%
# Stock split
df = df.withColumn("stockSplit", sqlFn.when(df["Stock Splits"] != 1, 1).otherwise(0))

# %%
# order by date 
w = Window.partitionBy().orderBy("date")

# %%
# Lagged column for the 'close' price (i.e., previous day's close)
df = df.withColumn("lagClose", sqlFn.lag(df.Close).over(w))

# %%
#  DailyChange - change in closing price from the previous day
df = df.withColumn("DailyChange", df.Close - df.lagClose)

# %%
# moving average for the closing prices
df = df.withColumn("movingAvgClose", sqlFn.avg(df.Close).over(w.rowsBetween(-6, 0)))

# %%
# drop any row having any Null 
df = df.dropna(how="any")

# %%
if SENTIMENT_ANALYSIS:
    consolidatedFeature = ["Open", "High", "Low", "Close", "Volume", "openCloseChange", 
                   "maxDayChange", "DailyChange", "movingAvgClose", 
                   "dividend", "stockSplit", "Sentiment"]
else:
    consolidatedFeature = ["Open", "High", "Low", "Close", "Volume", "openCloseChange", 
                   "maxDayChange", "DailyChange", "movingAvgClose", 
                   "dividend", "stockSplit"]
    print("Sentiment analysis disabled")

# %%
#store features in the vector column
assembler = VectorAssembler(inputCols=consolidatedFeature, outputCol="features")
df_assembled = assembler.transform(df)

# %%
# Split the data into a training set - 80% , 20% test set. 

trainingDataCount = int(df_assembled.count() * 0.8)
trainingData = df_assembled.orderBy("date").limit(trainingDataCount)
testData = df_assembled.subtract(trainingData)

# %%
# GBT Model Training
gbt = GBTRegressor(labelCol="Close", featuresCol="features", maxIter=10, maxBins =64, maxDepth =5,stepSize =0.25)

# %%
model = gbt.fit(trainingData)

# %%
predictions = model.transform(testData)

# %%
# Model Evaluation
# Compute the RMSE (Root Mean Squared Error) for the predictions
evaluator_rmse = RegressionEvaluator(labelCol="Close", predictionCol="prediction", metricName="rmse")

# %%
rmse = evaluator_rmse.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data =", rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 5.958398749994316

# %%
# Mean Absolute Error (MAE) and R-squared (R2)
for metric in ["mae", "r2"]:
    evaluator = RegressionEvaluator(labelCol="Close", predictionCol="prediction", metricName=metric)
    value = evaluator.evaluate(predictions)
    print(f"{metric.upper()}: {value}")
# Out:
# MAE: 5.0383267841752435
# R2: -1.3162013670172636

# %%
plt.figure(figsize=(12, 6))

# %%
preds = predictions.select("Date", "Close", "prediction").toPandas()

# %%
plt.plot(preds["Close"], label='Actual', color='blue')

# %%
plt.plot(preds["prediction"], label='Predicted', color='red', alpha=0.6)

# %%
plt.plot(preds.index, preds["Close"], label='Actual', color='blue')
plt.plot(preds.index, preds["prediction"], label='Predicted', color='red', alpha=0.6)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt

# Convert "Date" column to datetime type, with utc=True
preds['Date'] = pd.to_datetime(preds['Date'], utc=True)

# Filter data for the Last 2 months
six_months_ago = pd.Timestamp.now(tz='UTC') - timedelta(days=30*2)
preds_last_6_months = preds[preds['Date'] >= six_months_ago]

# Creating the plot
plt.figure(figsize=(12, 6))  # Setting the figure size

# Plotting actual values as blue bars
plt.bar(preds_last_6_months.index, preds_last_6_months["Close"], color='blue', width=0.6, label='Actual')

# Shifting the position of predicted values slightly to the right for better visualization
plt.bar(preds_last_6_months.index + 0.4, preds_last_6_months["prediction"], color='red', width=0.6, label='Predicted')

plt.xlabel('Index')  # Labeling x-axis
plt.ylabel('Close Price')  # Labeling y-axis
plt.title('Actual vs Predicted Adjusted Closing Prices for Last 6 Months')  # Setting the title of the plot
plt.legend()  # Showing the legend
plt.xticks(preds_last_6_months.index + 0.2, preds_last_6_months['Date'].dt.strftime('%Y-%m-%d'))  # Setting x-axis ticks with dates
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjusting layout for better visualization
plt.show()  # Displaying the plot

# %%
from matplotlib.dates import AutoDateLocator, AutoDateFormatter

# Prepare historical data for the past 1 month
end_date_past = datetime.now().strftime('%Y-%m-%d')
start_date_past = (datetime.now() - timedelta(days=30)).strftime('%Y-%m-%d')
past_data = df.filter((sqlFn.col("Date") >= start_date_past) & (sqlFn.col("Date") <= end_date_past))

# Apply the same feature engineering steps to past_data
# Assuming you've defined the feature_columns as before
consolidatedFeature = ["Open", "High", "Low", "Close", "Volume", "openCloseChange", 
                   "maxDayChange", "DailyChange", "movingAvgClose", 
                   "dividend", "stockSplit"]

# Assemble features
assembler = VectorAssembler(inputCols=consolidatedFeature, outputCol="features")
past_data_assembled = assembler.transform(past_data)

# Apply the trained model to make predictions for the past 1 month
past_predictions = model.transform(past_data_assembled)

# Plot the historical and predicted data for the past 1 month
past_data_pd = past_data.select("Date", "Close").toPandas()
past_pred_pd = past_predictions.select("Date", "prediction").toPandas()

last_date = datetime.strptime(end_date_past, '%Y-%m-%d')

# Prepare future data for the next 7 days using the last available data point
end_date_future = (datetime.now() + timedelta(days=30)).strftime('%Y-%m-%d')
future_dates = [last_date + timedelta(days=i) for i in range(1, 7)]  # Include next 7 days
future_df = spark.createDataFrame([(d,) for d in future_dates], ["Date"])
last_data_point = df.orderBy("Date", ascending=False).limit(1)  # Get the last available data point
future_df = future_df.crossJoin(last_data_point.drop("Date"))

# Apply the same feature engineering steps to future_df
future_df = future_df.withColumn("lagClose", sqlFn.lag(future_df.Close).over(Window.orderBy("Date")))
future_df = future_df.withColumn("dayChange", (future_df.Close - future_df.Open) / future_df.Open)
future_df = future_df.withColumn("maxDayChange", future_df.High - future_df.Low)
future_df = future_df.withColumn("DailyChange", future_df.Close - future_df.lagClose)
future_df = future_df.withColumn("movingAvgClose", sqlFn.avg(future_df.Close).over(Window.rowsBetween(-6, 0)))
future_df = future_df.withColumn("dividend", sqlFn.when(future_df["Dividends"] > 0, 1).otherwise(0))
future_df = future_df.withColumn("stockSplit", sqlFn.when(future_df["Stock Splits"] != 1, 1).otherwise(0))
future_df = future_df.dropna()
future_df_assembled = assembler.transform(future_df)

# Apply the trained model to make predictions for the next 7 days
future_predictions = model.transform(future_df_assembled)

# Plot the predicted data for the next 7 days
future_pred_pd = future_predictions.select("Date", "prediction").toPandas()

# Convert date column to pandas datetime object
future_pred_pd["Date"] = pd.to_datetime(future_pred_pd["Date"])

# Plot the predicted data for the next 7 days
plt.figure(figsize=(12, 6))
plt.plot(future_pred_pd["Date"], future_pred_pd["prediction"], label='Predicted Close (Next 30 Days)', color='green', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Predicted Close Prices (Next 30 Days)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Terminate the Spark session
spark.stop()
